# %%
import pyautogui
import time
import pandas as pd


pyautogui.PAUSE = 1;

#Entrando no sistema (chrome)

pyautogui.press("win");
pyautogui.write("chrome");
pyautogui.press("enter");
pyautogui.hotkey("ctrl", "t");

#Realizando o login na plataforma

time.sleep(2);
pyautogui.write("url");
pyautogui.press("enter");
time.sleep(2);

pyautogui.click(x=398, y=-737);
pyautogui.write("user");
pyautogui.click(x=368, y=-657);
pyautogui.write("123456");
pyautogui.click(x=376, y=-588);

#fazendo o download da base de dados

time.sleep(3);
pyautogui.click(x=-80, y=-803);
pyautogui.click(x=-12, y=-302);
pyautogui.click(x=-292, y=-647);
pyautogui.hotkey("ctrl", "a");
pyautogui.press("backspace");
pyautogui.write("nome da base");
pyautogui.click(x=228, y=-575);

# %%
#calculando indicadores

tabela = pandas.read_csv(r"local da pasta", sep=";");
display(tabela);

total_gasto = tabela["ValorFinal"].sum();
quantidade = tabela["Quantidade"].sum();
preco_medio = total_gasto / quantidade;

print(total_gasto);
print(quantidade);
print(preco_medio);


import pyperclip

#preenchimento do e-mail

pyautogui.hotkey("ctrl", "t");
pyautogui.write("url do e-mail");
pyautogui.press("enter");
time.sleep(5);
pyautogui.click(x=-496, y=-921);
pyautogui.write("e-mail do requerente");
pyautogui.press("enter");
pyautogui.press("tab");
pyperclip.copy("assunto");
pyautogui.hotkey("ctrl", "v");
pyautogui.press("tab");
texto = """Segue dados:

Total de gastos: R${total_gasto:,.2f}
Quantidade: R${quantidade:,.2f}
Preço médio: R${preco_medio:,.2f}

att,

...,

""";
pyperclip.copy(texto);
pyautogui.hotkey("ctrl", "v");
pyautogui.hotkey("ctrl", "enter");
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...
